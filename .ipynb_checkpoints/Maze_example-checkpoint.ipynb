# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 시각적 미로 구현
# matplot을 통해 미로를 만들어 줍니다.

# %%
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

plt.plot([1, 1], [0, 1], color="red", linewidth=2)
plt.plot([1, 2], [2, 2], color="red", linewidth=2)
plt.plot([2, 2], [2, 1], color="red", linewidth=2)
plt.plot([2, 3], [1, 1], color="red", linewidth=2)

plt.text(0.5, 2.5, "S0", size=14, ha="center")
plt.text(1.5, 2.5, "S1", size=14, ha="center")
plt.text(2.5, 2.5, "S2", size=14, ha="center")
plt.text(0.5, 1.5, "S3", size=14, ha="center")
plt.text(1.5, 1.5, "S4", size=14, ha="center")
plt.text(2.5, 1.5, "S5", size=14, ha="center")
plt.text(0.5, 0.5, "S6", size=14, ha="center")
plt.text(1.5, 0.5, "S7", size=14, ha="center")
plt.text(2.5, 0.5, "S8", size=14, ha="center")
plt.text(0.5, 2.3, "START", ha="center")
plt.text(2.5, 0.3, "GOAL", ha="center")

ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)

line, = ax.plot([0.5], [2.5], marker="o", color="g", markersize=60)

# %% [markdown]
# # 정책 반복 알고리즘

# %% [markdown]
# ## 정책의 초기값 설정
# 에이전트의 정책을 결정하는 파라미터의 초기값인 theta_0을 설정해줍니다.
# 각 줄은 state 0~7 각각 취할 수 있는 행동들을 의미합니다.
# 행동은 각각 상, 우, 하, 좌에 해당됩니다.

# %%
theta_0 = np.array([[np.nan, 1, 1, np.nan],      # s0
                    [np.nan, 1, np.nan, 1],      # s1
                    [np.nan, np.nan, 1, 1],      # s2
                    [1, 1, 1, np.nan],           # s3
                    [np.nan, np.nan, 1, 1],      # s4
                    [1, np.nan, np.nan, np.nan], # s5
                    [1, np.nan, np.nan, np.nan], # s6
                    [1, 1, np.nan, np.nan],      # s7
                    # s8은 목표 지점이기에 정책 x
                   ])

np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ## 초기 정책 정의
# 파라미터 theta를 기반으로 정책을 계산합니다.

# %% [markdown]
# ### 단순 비율 계산
# 이 계산 과정은 각 행동이 똑같은 확률을 가지도록 합니다.

# %%
def simple_convert_into_pi_from_theta(theta):
    [m, n] = theta.shape
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])
        
    pi = np.nan_to_num(pi)
    
    return pi

# %% [markdown]
# ### 소프트맥스 함수 계산
# 변화하는 파라미터가 음수가 되는 경우에도 정책을 계산할 수 있도록 항상 양수의 값을 내놓는 지수 함수로 정책 함수를 만들어 줍니다.
# $$ P(\theta_i)=\frac{exp(\beta \theta_i)}{exp(\beta \theta_1)+exp(\beta \theta_2)+\cdots} $$
# $$ = \frac{exp(\beta \theta_i)}{\sum_{j=1}^{N_a}exp(\beta \theta_j)} $$
# $\beta$는 행동이 무작위로 선택되는 정도를 의미한다. 작을수록 더욱 무작위로 선택된다.

# %%
def softmax_convert_into_pi_from_theta(theta):
    beta = 1.0
    [m, n] = theta.shape
    pi = np.zeros((m, n))
    
    exp_theta = np.exp(beta * theta)
    
    for i in range(0, m):
        pi[i, :] = exp_theta[i, :] / np.nansum(exp_theta[i, :])
        
    pi = np.nan_to_num(pi)
    
    return pi

# %%
# pi_0 = simple_convert_into_pi_from_theta(theta_0)
# pi_0 = softmax_convert_into_pi_from_theta(theta_0)
# pi_0

# %% [markdown]
# ## 이동과 도착 함수 정의
# 에이전트가 한 단계 이동하여 상태를 바꿀 수 있도록 함수를 만듭니다.
# 이 함수를 반복하여 도착 지점에 도달했는지 판단하는 함수도 만들어 줍니다.

# %%
def get_action_and_next_s(pi, s):
    direction = ["up", "right", "down", "left"]
    
    next_direction = np.random.choice(direction, p=pi[s, :])
    
    if next_direction == "up":
        action = 0
        s_next = s - 3
    elif next_direction == "right":
        action = 1
        s_next = s + 1
    elif next_direction == "down":
        action = 2
        s_next = s + 3
    elif next_direction == "left":
        action = 3
        s_next = s - 1
        
    return [action, s_next]

def goal_maze_ret_s_a(pi):
    s = 0
    s_a_history = [{'s':0, 'a':np.nan}]
    
    while (1):
        [action, next_s] = get_action_and_next_s(pi, s)
        s_a_history[-1]['a'] = action
        
        s_a_history.append({'s':next_s, 'a':np.nan})
        
        if next_s == 8:
            break
        else:
            s = next_s
            
    return s_a_history

# %% [markdown]
# ## 정책 수정
# Policy Gradient 알고리즘으로 파라미터를 수정한다.
# $$ \theta_{s_i, a_j}=\theta_{s_i, a_j}+\eta \cdot \Delta \theta_{s, a_j} $$
# $$ \Delta \theta_{s, a_j} = \{N(s_i, a_j)-P(s_i, a_j)N(s_i, a)\}/T $$
# $\eta$는 학습률로, 한 학습에 얼마나 수정되냐를 결정한다. 작을 수록 학습 속도가 늦어지고, 너무 높으면 오버피팅 된다.

# %%
def update_theta(theta, pi, s_a_history):
    eta = 0.1
    T = len(s_a_history)-1
    
    [m, n] = theta.shape
    delta_theta = theta.copy()
    
    for i in range(0, m):
        for j in range(0, n):
            if not np.isnan(theta[i, j]):
                SA_i = [SA for SA in s_a_history if SA['s'] == i]
                SA_ij = [SA for SA in SA_i if SA['a'] == j]
                
                if not SA_ij == [SA for SA in s_a_history if SA == {'s':i, 'a':j}]:
                    raise Exception("not equal error")
                
                N_i = len(SA_i)
                N_ij = len(SA_ij)
                
                delta_theta[i, j] = (N_ij - pi[i, j] * N_i) / T
            
    new_theta = theta + eta*delta_theta
    
    return new_theta

# %% [markdown]
# ## 정책 반복 알고리즘

# %%
# stop_epsilon = 10**-4

# theta = theta_0
# pi = pi_0

# is_continue = True
# count = 1
# while is_continue:
#     s_a_history = goal_maze_ret_s_a(pi)
#     new_theta = update_theta(theta, pi, s_a_history)
#     new_pi = softmax_convert_into_pi_from_theta(new_theta)
    
#     print(np.sum(np.abs(new_pi - pi)))
#     print("목표 지점에 이르기까지 걸린 단계 수:", len(s_a_history)-1)
    
#     if np.sum(np.abs(new_pi - pi)) < stop_epsilon:
#         is_continue = False
#     else:
#         theta = new_theta
#         pi = new_pi

# %%
# print(pi)

# %% [markdown]
# # 가치 반복 알고리즘

# %% [markdown]
# ## 가치 함수 무작위 정의
# 가치 반복 알고리즘에서 사용할 가치 함수 Q를 정의해준다.
# 초기값은 무작위로 정해준다.

# %%
[a, b] = theta_0.shape
Q = np.random.rand(a, b) * theta_0 * 0.1
print(Q)
# Out:
# [[  nan 0.098 0.081   nan]
#  [  nan 0.021   nan 0.068]
#  [  nan   nan 0.031 0.023]
#  [0.085 0.036 0.073   nan]
#  [  nan   nan 0.091 0.046]
#  [0.058   nan   nan   nan]
#  [0.022   nan   nan   nan]
#  [0.008 0.044   nan   nan]]

# %% [markdown]
# ## 무작위 정책 정의

# %%
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %% [markdown]
# ## $\epsilon$-greedy 알고리즘 구현

# %%
def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]

    if np.random.rand() < epsilon:
        next_direction = np.random.choice(direction, p=pi_0[s, :])
    else:
        next_direction = direction[np.nanargmax(Q[s, :])]
                
    action = direction.index(next_direction)
        
    return action

def get_s_next(s, a, Q, epsilon):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a]
    
    if next_direction == "up":
        s_next = s - 3
    elif next_direction == "right":
        s_next = s + 1
    elif next_direction == "down":
        s_next = s + 3
    elif next_direction == "left":
        s_next = s - 1
        
    return s_next

# %% [markdown]
# ### Sarsa 알고리즘 구현
# 벨만 방정식에 기초하여 TD 오차를 바탕으로 행동가치 함수 Q를 수정하는 알고리즘을 만들어준다.

# %%
def Sarsa(s, a, r, s_next, a_next, Q, eta, gamma):
    if s_next == 8:
        Q[s, a] = Q[s, a] + eta*(r-Q[s, a])
    else:
        Q[s, a] = Q[s, a] + eta*(r + gamma*Q[s_next, a_next] - Q[s, a])
        
    return Q

# %% [markdown]
# ### Q-learning 알고리즘 구현

# %%
def Q_learning(s, a, r, s_next, a_next, Q, eta, gamma):
    if s_next == 8:
        Q[s, a] = Q[s, a] + eta*(r-Q[s, a])
    else:
        Q[s, a] = Q[s, a] + eta*(r + gamma*np.nanmax(Q[s_next, :]) - Q[s, a])
        
    return Q

# %% [markdown]
# ## 도착 함수 구현

# %%
def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi, update_func):
    s = 0
    a = a_next = get_action(s, Q, epsilon, pi)
    s_a_history = [{'s':0, 'a':np.nan}]
    
    while True:
        a = a_next
        
        s_a_history[-1]['a'] = a
        
        s_next = get_s_next(s, a, Q, epsilon)
        
        s_a_history.append({'s':s_next, 'a':np.nan})
        
        if s_next == 8:
            r = 1
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            
        Q = update_func(s, a, r, s_next, a_next, Q, eta, gamma)
        
        if s_next == 8:
            break
        else:
            s = s_next
            
    return [s_a_history, Q]

# %% [markdown]
# ## 가치 반복 알고리즘

# %%
eta = 0.1
gamma = 0.9
epsilon = 0.5
v = np.nanmax(Q, axis=1)
print(v)
is_continue = True
episode = 1

V = []
V.append(v)

while is_continue:
    print("에피소드:", episode)
    
    epsilon = epsilon / 2
    
#     [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0, update_func=Sarsa)
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0, update_func=Q_learning)
    
    new_v = np.nanmax(Q, axis=1)
    print(np.sum(np.abs(new_v - v)))
    v = new_v
    V.append(v)
    
    print("목표 지점에 이르기까지 걸린 단계 수:", len(s_a_history)-1)
    
    episode = episode + 1
    if episode > 100:
        break
# Out:
# [0.098 0.068 0.031 0.085 0.091 0.058 0.022 0.044]
# 에피소드: 1
# 0.1638397891608986
# 목표 지점에 이르기까지 걸린 단계 수: 84
# 에피소드: 2
# 0.0908647458488291
# 목표 지점에 이르기까지 걸린 단계 수: 6
# 에피소드: 3
# 0.10483417988934875
# 목표 지점에 이르기까지 걸린 단계 수: 30
# 에피소드: 4
# 0.16199501588018078
# 목표 지점에 이르기까지 걸린 단계 수: 168
# 에피소드: 5
# 0.09059319190124202
# 목표 지점에 이르기까지 걸린 단계 수: 6
# 에피소드: 6
# 0.0888979254903686
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 7
# 0.08796990223213305
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 8
# 0.08699966268731789
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 9
# 0.08597997082453057
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 10
# 0.0849038403026141
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 11
# 0.08376513042390883
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 12
# 0.0825589218905488
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 13
# 0.08128172441022748
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 14
# 0.0799315581823242
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 15
# 0.07850794298437595
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 16
# 0.07701182170549146
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 17
# 0.07544543950980957
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 18
# 0.07381219516564323
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 19
# 0.07211647727980536
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 20
# 0.07036349509190462
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 21
# 0.06855911099163248
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 22
# 0.06670967992295396
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 23
# 0.06482189924801474
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 24
# 0.06290267138909766
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 25
# 0.06095898058912419
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 26
# 0.05899778437959294
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 27
# 0.05702591977737781
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 28
# 0.05505002381323712
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 29
# 0.0530764676959663
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 30
# 0.0511113037125292
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 31
# 0.04916022383617047
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 32
# 0.04722852894489499
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 33
# 0.04532110752824453
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 34
# 0.04344242276997412
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 35
# 0.04159650692904021
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 36
# 0.03978696199408627
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 37
# 0.038016965651538004
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 38
# 0.0362892816799793
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 39
# 0.03460627396006305
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 40
# 0.03296992336709198
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 41
# 0.0313818468904703
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 42
# 0.029843318398936114
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 43
# 0.028355290541726585
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 44
# 0.0269184173428485
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 45
# 0.025533077107924018
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 46
# 0.02419939532041515
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 47
# 0.022917267256303386
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 48
# 0.02168638009353785
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 49
# 0.020506234334923712
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 50
# 0.019376164400787488
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 51
# 0.018295358281001817
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 52
# 0.01726287616504607
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 53
# 0.016277667994050504
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 54
# 0.015338589900502297
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 55
# 0.014444419519831775
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 56
# 0.013593870173717826
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 57
# 0.012785603937970014
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 58
# 0.012018243618533209
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 59
# 0.011290383667784898
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 60
# 0.010600600080098332
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 61
# 0.009947459310860607
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 62
# 0.00932952626696082
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 63
# 0.008745371419409897
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 64
# 0.008193577090362836
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 65
# 0.0076727429675761405
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 66
# 0.007181490899357379
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 67
# 0.006718469022489182
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 68
# 0.006282355274549678
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 69
# 0.005871860340580404
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 70
# 0.005485730082288365
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 71
# 0.005122747495949098
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 72
# 0.004781734242995439
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 73
# 0.00446155179496921
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 74
# 0.004161102232129399
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 75
# 0.0038793287325982195
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 76
# 0.003615215786505366
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 77
# 0.003367789167202151
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 78
# 0.003136115689267749
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 79
# 0.0029193027807536964
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 80
# 0.0027164978949071328
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 81
# 0.00252688778450616
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 82
# 0.002349697659922878
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 83
# 0.002184190250118956
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 84
# 0.002029664783974705
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 85
# 0.0018854559076507682
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 86
# 0.0017509325520981278
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 87
# 0.0016254967633368977
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 88
# 0.0015085825067603365
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 89
# 0.001399654455428112
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 90
# 0.001298206771144561
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 91
# 0.0012037618860278876
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 92
# 0.0011158692912809354
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 93
# 0.0010341043389664462
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 94
# 0.0009580670617637121
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 95
# 0.000887381014924471
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 96
# 0.0008216921439735403
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 97
# 0.0007606676810782975
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 98
# 0.0007039950724674338
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 99
# 0.0006513809387773684
# 목표 지점에 이르기까지 걸린 단계 수: 4
# 에피소드: 100
# 0.000602550069769725
# 목표 지점에 이르기까지 걸린 단계 수: 4

# %%
print(Q)
# Out:
# [[  nan 0.047 0.724   nan]
#  [  nan 0.023   nan 0.047]
#  [  nan   nan 0.036 0.031]
#  [0.048 0.809 0.047   nan]
#  [  nan   nan 0.9   0.046]
#  [0.037   nan   nan   nan]
#  [0.04    nan   nan   nan]
#  [0.008 1.      nan   nan]]

# %% [markdown]
# # 애니메이션 시각화
# 에이전트의 이동 과정을 애니메이션으로 만듭니다.

# %%
from matplotlib import animation
from IPython.display import HTML
import matplotlib.cm as cm

def init():
    line.set_data([], [])
    return (line,)

def animate_history(i):
    state = s_a_history[i]['s']
    x = (state % 3) + 0.5
    y = 2.5 - int(state / 3)
    line.set_data(x, y)
    return (line, )

anim_history = animation.FuncAnimation(fig, animate_history, init_func=init, frames=len(s_a_history), interval=100, repeat=False)

HTML(anim_history.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img1911a05b2abd4839ae9ed1bcd2570661">
#   <div class="anim-controls">
#     <input id="_anim_slider1911a05b2abd4839ae9ed1bcd2570661" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim1911a05b2abd4839ae9ed1bcd2570661.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim1911a05b2abd4839ae9ed1bcd2570661.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim1911a05b2abd4839ae9ed1bcd2570661.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim1911a05b2abd4839ae9ed1bcd2570661.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim1911a05b2abd4839ae9ed1bcd2570661.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim1911a05b2abd4839ae9ed1bcd2570661.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim1911a05b2abd4839ae9ed1bcd2570661.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim1911a05b2abd4839ae9ed1bcd2570661.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim1911a05b2abd4839ae9ed1bcd2570661.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim1911a05b2abd4839ae9ed1bcd2570661.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select1911a05b2abd4839ae9ed1bcd2570661" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_1911a05b2abd4839ae9ed1bcd2570661"
#              checked>
#       <label for="_anim_radio1_1911a05b2abd4839ae9ed1bcd2570661">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_1911a05b2abd4839ae9ed1bcd2570661"
#              >
#       <label for="_anim_radio2_1911a05b2abd4839ae9ed1bcd2570661">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_1911a05b2abd4839ae9ed1bcd2570661"
#              >
#       <label for="_anim_radio3_1911a05b2abd4839ae9ed1bcd2570661">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img1911a05b2abd4839ae9ed1bcd2570661";
#     var slider_id = "_anim_slider1911a05b2abd4839ae9ed1bcd2570661";
#     var loop_select_id = "_anim_loop_select1911a05b2abd4839ae9ed1bcd2570661";
#     var frames = new Array(5);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAcmklEQVR4nO3de3BU9f3/8dcmu4EkmxR+gJiLJiiV\
# GH4iksAQaKUSlFiHWkVwEi9ALGql1q/EwTqleOnPjo1GBis/R+YLUbwrKAanWlLAMIAVwkX8clH5\
# 1ggELJCCkHuW/Xz/WMKXSyAJJDmf3X0+ZjIO2Uve+zF55uTk5ByXMcYIAGCdCKcHAAC0jEADgKUI\
# NABYikADgKUINABYikADgKUINABYikADgKUINABYikADgKUINABYikADgKUINABYikADgKUINABY\
# ikADgKUINABYikADgKUINABYikADgKUINABYikADgKUINABYikADgKUINABYikADgKUINABYikAD\
# gKUINABYikADgKUINABYikADgKUINABYikADgKUINABYikADgKUINABYikADgKUINABYikADgKUI\
# NABYikADgKXcTg9wPnr37q3U1FS

# %%
def animate_episode(i):
    line, = ax.plot([0.5], [2.5], marker="s", color=cm.jet(V[i][0]), markersize=85)
    line, = ax.plot([1.5], [2.5], marker="s", color=cm.jet(V[i][1]), markersize=85)
    line, = ax.plot([2.5], [2.5], marker="s", color=cm.jet(V[i][2]), markersize=85)
    line, = ax.plot([0.5], [1.5], marker="s", color=cm.jet(V[i][3]), markersize=85)
    line, = ax.plot([1.5], [1.5], marker="s", color=cm.jet(V[i][4]), markersize=85)
    line, = ax.plot([2.5], [1.5], marker="s", color=cm.jet(V[i][5]), markersize=85)
    line, = ax.plot([0.5], [0.5], marker="s", color=cm.jet(V[i][6]), markersize=85)
    line, = ax.plot([1.5], [0.5], marker="s", color=cm.jet(V[i][7]), markersize=85)
    line, = ax.plot([2.5], [0.5], marker="s", color=cm.jet(1.0), markersize=85)
    return (line, )

anim_episode = animation.FuncAnimation(fig, animate_episode, init_func=init, frames=len(V), interval=100, repeat=False)

HTML(anim_episode.to_jshtml())
# Out:
# 101
